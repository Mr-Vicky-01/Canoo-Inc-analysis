# %% [markdown]
# ## Importing Dependencies

# %%
from bs4 import BeautifulSoup
import requests
import openpyxl
import pandas as pd
import csv
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Scaping the canoo income statement from https://www.marketwatch.com/investing/stock/goev/financials?mod=mw_quote_tab

# %%
try:
    url = 'https://www.marketwatch.com/investing/stock/goev/financials?mod=mw_quote_tab'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", class_='table table--overflow align--right')
    table_row = soup.find("tbody", class_='table__body row-hover').find_all('tr')

    with open("canoo_income_statement.csv", "w", newline="") as csv_file:
        csv_writer = csv.writer(csv_file)
        
        # Write header
        csv_writer.writerow(["item", "2018", "2019", "2020", "2021",'2022','nan'])

        for data in table_row:
            rows = data.find_all('td')
            row = []
            for j in rows:
                val = j.find_all('div', class_='cell__content')[0]
                row.append(val.get_text(strip=True))
            csv_writer.writerow(row)
            print(row)

except Exception as e:
    print(f"Error: {e}")

print("CSV file created successfully.")
# Out:
# ['Sales/Revenue', '-', '-', '2.55M', '-', '-', '']
# ['Sales Growth', '-', '-', '-', '-', '-', '']
# ['Cost of Goods Sold (COGS) incl. D&A', '-', '-', '7.8M', '9.97M', '13.91M', '']
# ['COGS Growth', '-', '-', '-', '27.86%', '39.55%', '']
# ['COGS excluding D&A', '-', '-', '38K', '-', '-', '']
# ['Depreciation & Amortization Expense', '-', '-', '7.76M', '9.97M', '13.91M', '']
# ['Depreciation', '-', '-', '7.76M', '9.97M', '13.91M', '']
# ['Amortization of Intangibles', '-', '-', '-', '-', '-', '']
# ['Gross Income', '-', '-', '(5.25M)', '(9.97M)', '(13.91M)', '']
# ['Gross Income Growth', '-', '-', '-', '-90.03%', '-39.55%', '']
# ['Gross Profit Margin', '-', '-', '-', '-', '-', '']
# ['SG&A Expense', '3K', '3.25M', '194.47M', '439.94M', '492.89M', '']
# ['SGA Growth', '-', '108,333.33%', '5,878.27%', '126.22%', '12.04%', '']
# ['Research & Development', '-', '-', '142.86M', '246.25M', '299.22M', '']
# ['Other SG&A', '3K', '3.25M', '51.61M', '193.69M', '193.67M', '']
# ...

# %% [markdown]
# ### Convert the scarped csv file into pandas DataFrame

# %%
df = pd.read_csv('canoo_income_statement.csv').drop("nan", axis=1)
df.head()
# Out:
#                                   item 2018 2019   2020    2021    2022
# 0                        Sales/Revenue    -    -  2.55M       -       -
# 1                         Sales Growth    -    -      -       -       -
# 2  Cost of Goods Sold (COGS) incl. D&A    -    -   7.8M   9.97M  13.91M
# 3                          COGS Growth    -    -      -  27.86%  39.55%
# 4                   COGS excluding D&A    -    -    38K       -       -

# %% [markdown]
# Scaping the Tesla income statement from https://www.marketwatch.com/investing/stock/tsla/financials/income

# %%
try:
    url = 'https://www.marketwatch.com/investing/stock/tsla/financials/income'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", class_='table table--overflow align--right')
    table_row = soup.find("tbody", class_='table__body row-hover').find_all('tr')

    with open("tesla_income_statement.csv", "w", newline="") as csv_file:
        csv_writer = csv.writer(csv_file)
        
        # Write header
        csv_writer.writerow(["item", "2023", "None"])

        for data in table_row:
            rows = data.find_all('td')
            row = []
            for j in rows:
                val = j.find_all('div', class_='cell__content')[0]
                row.append(val.get_text(strip=True))
            csv_writer.writerow(row)
            print(row)

except Exception as e:
    print(f"Error: {e}")

print("CSV file created successfully.")
# Out:
# ['Sales/Revenue', '96.77B', '']
# ['Sales Growth', '-', '']
# ['Cost of Goods Sold (COGS) incl. D&A', '79.11B', '']
# ['COGS Growth', '-', '']
# ['COGS excluding D&A', '74.45B', '']
# ['Depreciation & Amortization Expense', '4.67B', '']
# ['Depreciation', '3.57B', '']
# ['Amortization of Intangibles', '1.1B', '']
# ['Gross Income', '17.66B', '']
# ['Gross Income Growth', '-', '']
# ['Gross Profit Margin', '18.25%', '']
# ['SG&A Expense', '8.77B', '']
# ['SGA Growth', '-', '']
# ['Research & Development', '3.97B', '']
# ['Other SG&A', '4.8B', '']
# ['Other Operating Expense', '-', '']
# ['Unusual Expense', '4M', '']
# ['EBIT after Unusual Expense', '8.89B', '']
# ['Non Operating Income/Expense', '176M', '']
# ['Non-Operating Interest Income', '1.07B', '']
# ['Equity in Affiliates (Pretax)', '-', '']
# ['Interest Expense', '156M', '']
# ['Interest Expense Growth', '-', '']
# ['Gross Interest Expense', '156M', '']
# ['Interest Capitalized', '-', '']
# ['Pretax Income', '9.97B', '']
# ...

# %% [markdown]
# Scaping the Rivian income statement from https://www.marketwatch.com/investing/stock/rivn/financials?mod=mw_quote_tab

# %%
try:
    url = 'https://www.marketwatch.com/investing/stock/rivn/financials?mod=mw_quote_tab'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", class_='table table--overflow align--right')
    table_row = soup.find("tbody", class_='table__body row-hover').find_all('tr')

    with open("rivian_income_statement.csv", "w", newline="") as csv_file:
        csv_writer = csv.writer(csv_file)
        
        # Write header
        csv_writer.writerow(["item", "2019", "2020", "2021", "2022", "None"])

        for data in table_row:
            rows = data.find_all('td')
            row = []
            for j in rows:
                val = j.find_all('div', class_='cell__content')[0]
                row.append(val.get_text(strip=True))
            csv_writer.writerow(row)
            print(row)

except Exception as e:
    print(f"Error: {e}")

print("CSV file created successfully.")
# Out:
# ['Sales/Revenue', '-', '-', '55M', '1.66B', '']
# ['Sales Growth', '-', '-', '-', '2,914.55%', '']
# ['Cost of Goods Sold (COGS) incl. D&A', '7M', '29M', '717M', '4.96B', '']
# ['COGS Growth', '-', '314.29%', '2,372.41%', '591.49%', '']
# ['COGS excluding D&A', '-', '-', '520M', '4.31B', '']
# ['Depreciation & Amortization Expense', '7M', '29M', '197M', '647M', '']
# ['Depreciation', '7M', '29M', '197M', '647M', '']
# ['Amortization of Intangibles', '-', '-', '-', '-', '']
# ['Gross Income', '(7M)', '(29M)', '(662M)', '(3.3B)', '']
# ['Gross Income Growth', '-', '-314.29%', '-2,182.76%', '-398.49%', '']
# ['Gross Profit Margin', '-', '-', '-', '-199.03%', '']
# ['SG&A Expense', '402M', '992M', '2.9B', '3.56B', '']
# ['SGA Growth', '-', '146.77%', '191.83%', '22.83%', '']
# ['Research & Development', '301M', '766M', '1.85B', '1.85B', '']
# ['Other SG&A', '101M', '226M', '1.05B', '1.71B', '']
# ['Other Operating Expense', '-', '-', '663M', '-', '']
# ...

# %% [markdown]
# Canoo Historical data Scarping from https://www.marketwatch.com/investing/stock/goev/download-data?startDate=1/2/2023&endDate=12/29/2023

# %%
try:
    url = 'https://www.marketwatch.com/investing/stock/goev/download-data?startDate=1/2/2023&endDate=12/29/2023'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", class_="table table--overflow align--center", attrs={"aria-label": "Historical Quotes data table"})
    table_row = soup.find("tbody", class_='table__body row-hover').find_all('tr')

    with open("canoo_historical_quotes.csv", "w", newline="") as csv_file:
        csv_writer = csv.writer(csv_file)
        
        # Write header
        csv_writer.writerow(["date", "open", "high", "low", "close", "volume"])

        for data in table_row:
            rows = data.find_all('td')
            row = []
            for j in rows:
                val = j.find_all('div', class_='cell__content')[0]
                row.append(val.get_text(strip=True))
            csv_writer.writerow(row)


except Exception as e:
    print(f"Error: {e}")

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %% [markdown]
# Rivian Historical data Scarping from https://www.marketwatch.com/investing/stock/rivn/download-data?startDate=1/2/2023&endDate=12/29/2023

# %%
try:
    url = 'https://www.marketwatch.com/investing/stock/rivn/download-data?startDate=1/2/2023&endDate=12/29/2023'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", class_="table table--overflow align--center", attrs={"aria-label": "Historical Quotes data table"})
    table_row = soup.find("tbody", class_='table__body row-hover').find_all('tr')

    with open("rivian_historical_quotes.csv", "w", newline="") as csv_file:
        csv_writer = csv.writer(csv_file)
        
        # Write header
        csv_writer.writerow(["date", "open", "high", "low", "close", "volume"])

        for data in table_row:
            rows = data.find_all('td')
            row = []
            for j in rows:
                val = j.find_all('div', class_='cell__content')[0]
                row.append(val.get_text(strip=True))
            csv_writer.writerow(row)

except Exception as e:
    print(f"Error: {e}")

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %% [markdown]
# Tesla Historical data Scarping from https://www.marketwatch.com/investing/stock/tsla/download-data?startDate=1/2/2023&endDate=12/29/2023

# %%
try:
    url = 'https://www.marketwatch.com/investing/stock/tsla/download-data?startDate=1/2/2023&endDate=12/29/2023'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find("table", class_="table table--overflow align--center", attrs={"aria-label": "Historical Quotes data table"})
    table_row = soup.find("tbody", class_='table__body row-hover').find_all('tr')

    with open("tesla_historical_quotes.csv", "w", newline="") as csv_file:
        csv_writer = csv.writer(csv_file)
        
        # Write header
        csv_writer.writerow(["date", "open", "high", "low", "close", "volume"])

        for data in table_row:
            rows = data.find_all('td')
            row = []
            for j in rows:
                val = j.find_all('div', class_='cell__content')[0]
                row.append(val.get_text(strip=True))
            csv_writer.writerow(row)

except Exception as e:
    print(f"Error: {e}")

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %% [markdown]
# ### Loading Income Statement into Pandas DataFrame

# %%
canoo_income_statement = pd.read_csv('canoo_income_statement.csv').drop('nan',axis=1)
rivian_income_statement = pd.read_csv("rivian_income_statement.csv").drop("None", axis=1)
tesla_income_statement = pd.read_csv("tesla_income_statement.csv").drop("None", axis=1)

# %%
canoo_income_statement.head()
# Out:
#                                   item 2018 2019   2020    2021    2022
# 0                        Sales/Revenue    -    -  2.55M       -       -
# 1                         Sales Growth    -    -      -       -       -
# 2  Cost of Goods Sold (COGS) incl. D&A    -    -   7.8M   9.97M  13.91M
# 3                          COGS Growth    -    -      -  27.86%  39.55%
# 4                   COGS excluding D&A    -    -    38K       -       -

# %%
canoo_income_statement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   item    57 non-null     object
#  1   2018    57 non-null     object
#  2   2019    57 non-null     object
#  3   2020    57 non-null     object
#  4   2021    57 non-null     object
#  5   2022    57 non-null     object
# dtypes: object(6)
# memory usage: 2.8+ KB

# %% [markdown]
# Function for Preprocession Data

# %%
def preprocess_(x):
    try:
        if x == '-':
            return 0
        else:
            return x
    except Exception as e:
        print('Error in preprocess_:', e)

# %%
def remove_paranthesis(x):
    try:
        return str(x).replace("(", "").replace(")", "")
    except Exception as e:
        print('Error in remove_paranthesis:', e)

# %%
def percentage(x):
    try:
        if isinstance(x, str):
            val = x[-1]
            if val == "%":
                x = x.replace(',', '')[:-1]
                return float(x) / 100
        return x
    except Exception as e:
        print('Error in percentage:', e)

# %%
def replace_digits(x):
    try:
        x = str(x)
        val = x[-1].lower()
        if val.isdigit(): 
            return float(x)
        elif val == 'k':
            return float(x[:-1]) * 1000
        elif val == 'm':
            return float(x[:-1]) * 1000000
        elif val == 'b':
            return float(x[:-1]) * 1000000000
        else:
            return float(x)
    except Exception as e:
        print('Error in replace_digits:', e)

# %%
def preprocess_df(column):
    try:
        column = column.apply(preprocess_)
        column = column.apply(remove_paranthesis)
        column = column.apply(percentage)
        column = column.apply(replace_digits)
        return column
    except Exception as e:
        print('Error in preprocess_df:', e)

# %% [markdown]
# Cleaning the Data using **preprocess_df** Function()

# %%
for id,column in enumerate(canoo_income_statement):
    if id >=1:
        canoo_income_statement[column] = preprocess_df(canoo_income_statement[column])
    else:
        pass

# %%
canoo_income_statement.head()
# Out:
#                                   item  2018  2019       2020          2021  \
# 0                        Sales/Revenue   0.0   0.0  2550000.0  0.000000e+00
# 1                         Sales Growth   0.0   0.0        0.0  0.000000e+00
# 2  Cost of Goods Sold (COGS) incl. D&A   0.0   0.0  7800000.0  9.970000e+06
# 3                          COGS Growth   0.0   0.0        0.0  2.786000e-01
# 4                   COGS excluding D&A   0.0   0.0    38000.0  0.000000e+00
#
#            2022
# 0  0.000000e+00
# 1  0.000000e+00
# 2  1.391000e+07
# 3  3.955000e-01
# 4  0.000000e+00

# %%
for id,column in enumerate(rivian_income_statement):
    if id >=1:
        rivian_income_statement[column] = preprocess_df(rivian_income_statement[column])
    else:
        pass
rivian_income_statement
# Out:
#                                          item          2019          2020  \
# 0                               Sales/Revenue  0.000000e+00  0.000000e+00
# 1                                Sales Growth  0.000000e+00  0.000000e+00
# 2         Cost of Goods Sold (COGS) incl. D&A  7.000000e+06  2.900000e+07
# 3                                 COGS Growth  0.000000e+00  3.142900e+00
# 4                          COGS excluding D&A  0.000000e+00  0.000000e+00
# 5         Depreciation & Amortization Expense  7.000000e+06  2.900000e+07
# 6                                Depreciation  7.000000e+06  2.900000e+07
# 7                 Amortization of Intangibles  0.000000e+00  0.000000e+00
# 8                                Gross Income  7.000000e+06  2.900000e+07
# 9                         Gross Income Growth  0.000000e+00 -3.142900e+00
# 10                        Gross Profit Margin  0.000000e+00  0.000000e+00
# 11                               SG&A Expense  4.020000e+08  9.920000e+08
# ...

# %%
tesla_income_statement["2023"] = preprocess_df(tesla_income_statement["2023"])
tesla_income_statement
# Out:
#                                          item          2023
# 0                               Sales/Revenue  9.677000e+10
# 1                                Sales Growth  0.000000e+00
# 2         Cost of Goods Sold (COGS) incl. D&A  7.911000e+10
# 3                                 COGS Growth  0.000000e+00
# 4                          COGS excluding D&A  7.445000e+10
# 5         Depreciation & Amortization Expense  4.670000e+09
# 6                                Depreciation  3.570000e+09
# 7                 Amortization of Intangibles  1.100000e+09
# 8                                Gross Income  1.766000e+10
# 9                         Gross Income Growth  0.000000e+00
# 10                        Gross Profit Margin  1.825000e-01
# 11                               SG&A Expense  8.770000e+09
# 12                                 SGA Growth  0.000000e+00
# 13                     Research & Development  3.970000e+09
# 14                                 Other SG&A  4.800000e+09
# ...

# %% [markdown]
# ### Load Historical_quotes CSV Data into DataFarame

# %%
tesla_historical_quotes = pd.read_csv('tesla_historical_quotes.csv',parse_dates=['Date'])
canoo_historical_quotes = pd.read_csv('canoo_historical_quotes.csv',parse_dates=['Date'])
rivian_historical_quotes = pd.read_csv('rivian_historical_quotes.csv',parse_dates=['Date'])

# %%
tesla_historical_quotes
# Out:
#          Date    Open    High     Low   Close         Volume
# 0  2023-12-01  233.14  265.13  228.20  248.48  2,295,511,874
# 1  2023-11-01  204.04  252.75  197.85  240.08  2,652,010,466
# 2  2023-10-01  244.81  268.94  194.07  200.84  2,591,243,957
# 3  2023-09-01  257.26  278.98  234.58  250.22  2,440,633,603
# 4  2023-08-01  266.26  266.47  212.36  258.08  2,503,253,375
# 5  2023-07-01  276.49  299.29  254.12  267.43  2,393,588,305
# 6  2023-06-01  202.59  276.99  199.37  261.77  3,443,091,812
# 7  2023-05-01  163.17  204.48  158.83  203.93  2,682,606,241
# 8  2023-04-01  199.91  202.69  152.37  164.31  2,505,176,265
# 9  2023-03-01  206.21  207.79  163.91  207.46  3,312,555,329
# 10 2023-02-01  173.89  217.65  169.93  205.71  3,625,947,252
# 11 2023-01-01  118.47  180.68  101.81  173.22  3,897,499,359

# %%
tesla_historical_quotes['Month'] = tesla_historical_quotes.Date.dt.month
canoo_historical_quotes['Month'] = canoo_historical_quotes.Date.dt.month
rivian_historical_quotes['Month'] = rivian_historical_quotes.Date.dt.month

# %% [markdown]
# ### Finding Market Trend Using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
plt.plot(tesla_historical_quotes['Month'],tesla_historical_quotes['Close'],color='green',label='close')
plt.plot(tesla_historical_quotes['Month'],tesla_historical_quotes['Open'],color='blue',label='open')
plt.legend()
plt.title('tesla stock price 2023')
plt.ylabel('price in dollar($)')
plt.xlabel('month')
plt.grid(True,alpha=0.6);

# %%
# plt.figure(facecolor='black')
plt.plot(canoo_historical_quotes['Month'],canoo_historical_quotes['Close'],color='red',label='close')
plt.plot(canoo_historical_quotes['Month'],canoo_historical_quotes['Open'],color='blue',label='open')
plt.legend()
plt.title('canoo stock price 2023')
plt.ylabel('price in dollar($)')
plt.xlabel('month')
plt.grid(True,alpha=0.6)

# %%
plt.plot(rivian_historical_quotes['Month'],rivian_historical_quotes['Close'],color='green',label='close')
plt.plot(rivian_historical_quotes['Month'],rivian_historical_quotes['Open'],color='blue',label='open')
plt.legend() 
plt.title('rivian stock price 2023')
plt.ylabel('price in dollar($)')
plt.xlabel('month')
plt.grid(True,which='major',alpha=0.6)

# %% [markdown]
# ### Market Size Comparision

# %%
import matplotlib.pyplot as plt

company_names = ["Canoo", "Tesla", "Rivian"]
# vehicle deliveries collected from google
deliveries = [0, 1310000, 24500]

# plt.figure(figsize=(5, 6))
plt.barh(company_names, deliveries, color=['blue', 'green', 'orange'])
plt.xlabel("Vehicle Deliveries")
plt.title("Vehicle Deliveries Comparison")
plt.gca().invert_yaxis()  # Invert y-axis for readability
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

company_names = ["Canoo", "Tesla", "Rivian"]
revenues = [0, 81460, 536]  # Millions USD

# plt.figure(figsize=(10, 6))
plt.barh(company_names, revenues, color=['blue', 'green', 'orange'])
plt.xlabel("Revenue (Millions USD)")
plt.title("Revenue Comparison")
plt.gca().invert_yaxis()  # Invert y-axis for readability
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

company_names = ["Canoo", "Tesla", "Rivian"]
market_caps = [575.77, 741170, 26090]  # Millions USD

# plt.figure(figsize=(10, 6))
plt.barh(company_names, market_caps, color=['blue', 'green', 'orange'])
plt.xlabel("Market Capitalization (Millions USD)")
plt.title("Market Capitalization Comparison")
plt.gca().invert_yaxis()  # Invert y-axis for readability
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gross Income

# %%
gross_income = canoo_income_statement[canoo_income_statement['item']=='Gross Income']

# %%
# canoo 
year = []
income = []

for val in canoo_income_statement[canoo_income_statement['item']=='Gross Income'].items():
     if val[0] !='item':
        year.append(val[0])

    

for i in gross_income.loc[8]:
    if i !='Gross Income':
      income.append(i) 

# rivian 
rivian_year = []
rivian_income = []
for val in rivian_income_statement[rivian_income_statement['item']=='Gross Income'].items():
     if val[0] !='item':
        rivian_year.append(val[0])


for i in rivian_income_statement[rivian_income_statement['item']=='Gross Income'].loc[8]:
    if i !='Gross Income':
      rivian_income.append(i)

# %%
income
# Out:
# [0.0, 0.0, 5250000.0, 9970000.0, 13910000.0]

# %%
year
# Out:
# ['2018', '2019', '2020', '2021', '2022']

# %%
rivian_year
# Out:
# ['2019', '2020', '2021', '2022']

# %%
rivian_income
# Out:
# [7000000.0, 29000000.0, 662000000.0, 3300000000.0]

# %%
plt.plot(year,income,color='red',label='canoo')
plt.plot(rivian_year,rivian_income,color ='green',label='rivian')
plt.xlabel('year')
plt.title('gross Income Comparison')
plt.grid()
plt.legend()
plt.ticklabel_format(axis='y', style='plain', useOffset=False, scilimits=(1, 1e6))
plt.xticks(rotation=90);

# %% [markdown]
# ####  Market Global Share 2023

# %%
import matplotlib.pyplot as plt

# Define competitor names and market shares
competitors = ["Tesla", "Rivian", "Canoo"]
market_shares = [25, 2, 0]

# Create a pie chart
plt.pie(market_shares, labels=competitors, autopct="%1.1f%%")
plt.title("Electric Vehicle Market Share (Q3 2023)")

# Show the plot
plt.show()
